# %%
import os
import datetime
import pandas as pd
import sqlite3

# %% [markdown]
# # 일별 좌석점유율(James)

# %%
# 일별 좌석점유율 http://www.kobis.or.kr/kobis/business/stat/boxs/findDailySeatTicketList.do
    
NAME = 'findDailySeatTicketList'
URL = f'http://www.kobis.or.kr/kobis/business/stat/boxs/{NAME}.do'

date = datetime.date(2015, 1, 1)

# while date < datetime.date(2015, 1, 15): # 테스트용
while date < datetime.date(2019, 11, 1):
    start_date = date.isoformat()
    end_date = (date + datetime.timedelta(days=6)).isoformat()
    print(start_date, '~', end_date)
    os.system(f'curl "{URL}?loadEnd=0&dmlMode=excel&' \
              f'startDate={start_date}&endDate={end_date}&repNationCd=1&searchType=2"' \
              f' > 일별좌석점유율-{start_date}.html')
    date += datetime.timedelta(days=7)
# Out:
# 2015-01-01 ~ 2015-01-07
# 2015-01-08 ~ 2015-01-14

# %%
df = pd.DataFrame()

date = datetime.date(2015, 1, 1)

# while date < datetime.date(2015, 1, 15): # 테스트용
while date < datetime.date(2019, 11, 1):
    start_date = date.isoformat()

    seat = pd.read_html(f'일별좌석점유율-{start_date}.html', encoding='utf-8')

    for i in range(1,8)[::-1]:
         df2 = seat[i][:-1]
         df = pd.concat([df, df2])
        
    date += datetime.timedelta(days=7)

# %%
connection = sqlite3.connect('seat.db')
df.to_sql('seat_daily_propotion', connection, index=False
#           , if_exists='replace' # 같은 db 에 덮어쓰는 코드
         )
pd.read_sql('select * from seat_daily_propotion', connection)

# %% [markdown]
# # 일별 상영점유율(William)

# %%
# 일별 상영점유율 http://www.kobis.or.kr/kobis/business/stat/boxs/findDailyShowTicketList.do

NAME = 'findDailyShowTicketList'
URL = f'http://www.kobis.or.kr/kobis/business/stat/boxs/{NAME}.do'

date = datetime.date(2015, 1, 1)

# while date < datetime.date(2015, 1, 15): # 테스트용
while date < datetime.date(2019, 11, 1):
    start_date = date.isoformat()
    end_date = (date + datetime.timedelta(days=6)).isoformat()
    print(start_date, '~', end_date)
    os.system(f'curl "{URL}?loadEnd=0&dmlMode=excel&' \
              f'startDate={start_date}&endDate={end_date}&repNationCd=1"' \
              f' > 일별상영점유율-{start_date}.html')
    date += datetime.timedelta(days=7)
# Out:
# 2015-01-01 ~ 2015-01-07
# 2015-01-08 ~ 2015-01-14
# 2015-01-15 ~ 2015-01-21
# 2015-01-22 ~ 2015-01-28
# 2015-01-29 ~ 2015-02-04
# 2015-02-05 ~ 2015-02-11
# 2015-02-12 ~ 2015-02-18
# 2015-02-19 ~ 2015-02-25
# 2015-02-26 ~ 2015-03-04
# 2015-03-05 ~ 2015-03-11
# 2015-03-12 ~ 2015-03-18
# 2015-03-19 ~ 2015-03-25
# 2015-03-26 ~ 2015-04-01
# 2015-04-02 ~ 2015-04-08
# 2015-04-09 ~ 2015-04-15
# 2015-04-16 ~ 2015-04-22
# 2015-04-23 ~ 2015-04-29
# 2015-04-30 ~ 2015-05-06
# 2015-05-07 ~ 2015-05-13
# 2015-05-14 ~ 2015-05-20
# 2015-05-21 ~ 2015-05-27
# 2015-05-28 ~ 2015-06-03
# 2015-06-04 ~ 2015-06-10
# 2015-06-11 ~ 2015-06-17
# 2015-06-18 ~ 2015-06-24
# 2015-06-25 ~ 2015-07-01
# 2015-07-02 ~ 2015-07-08
# 2015-07-09 ~ 2015-07-15
# 2015-07-16 ~ 2015-07-22
# 2018-08-16 ~ 2018-08-22
# 2018-08-23 ~ 2018-08-29
# 2018-08-30 ~ 2018-09-05
# 2018-09-06 ~ 2018-09-12
# 2018-09-13 ~ 2018-09-19
# 2018-09-20 ~ 2018-09-26
# 2018-09-27 ~ 2018-10-03
# 2018-10-04 ~ 2018-10-10
# 2018-10-11 ~ 2018-10-17
# 2018-10-18 ~ 2018-10-24
# 2018-10-25 ~ 2018-10-31
# 2018-11-01 ~ 2018-11-07
# 2018-11-08 ~ 2018-11-14
# 2018-11-15 ~ 2018-11-21
# 2018-11-22 ~ 2018-11-28
# 2018-11-29 ~ 2018-12-05
# 2018-12-06 ~ 2018-12-12
# 2018-12-13 ~ 2018-12-19
# 2018-12-20 ~ 2018-12-26
# 2018-12-27 ~ 2019-01-02
# 2019-01-03 ~ 2019-01-09
# 2019-01-10 ~ 2019-01-16
# 2019-01-17 ~ 2019-01-23
# 2019-01-24 ~ 2019-01-30
# 2019-01-31 ~ 2019-02-06
# 2019-02-07 ~ 2019-02-13
# 2019-02-14 ~ 2019-02-20
# 2019-02-21 ~ 2019-02-27
# 2019-02-28 ~ 2019-03-06
# 2019-03-07 ~ 2019-03-13
# 2019-03-14 ~ 2019-03-20
# 2019-03-21 ~ 2019-03-27
# 2019-03-28 ~ 2019-04-03
# 2019-04-04 ~ 2019-04-10
# 2019-04-11 ~ 2019-04-17
# 2019-04-18 ~ 2019-04-24
# 2019-04-25 ~ 2019-05-01
# 2019-05-02 ~ 2019-05-08
# 2019-05-09 ~ 2019-05-15
# 2019-05-16 ~ 2019-05-22
# 2019-05-23 ~ 2019-05-29
# 2019-05-30 ~ 2019-06-05
# 2019-06-06 ~ 2019-06-12
# 2019-06-13 ~ 2019-06-19
# 2019-06-20 ~ 2019-06-26
# 2019-06-27 ~ 2019-07-03
# 2019-07-04 ~ 2019-07-10
# 2019-07-11 ~ 2019-07-17
# 2019-07-18 ~ 2019-07-24
# 2019-07-25 ~ 2019-07-31
# 2019-08-01 ~ 2019-08-07
# 2019-08-08 ~ 2019-08-14
# 2019-08-15 ~ 2019-08-21
# 2019-08-22 ~ 2019-08-28
# 2019-08-29 ~ 2019-09-04
# 2019-09-05 ~ 2019-09-11
# 2019-09-12 ~ 2019-09-18
# 2019-09-19 ~ 2019-09-25
# 2019-09-26 ~ 2019-10-02
# 2019-10-03 ~ 2019-10-09
# 2019-10-10 ~ 2019-10-16
# 2019-10-17 ~ 2019-10-23
# 2019-10-24 ~ 2019-10-30
# 2019-10-31 ~ 2019-11-06

# %%
df = pd.DataFrame()

date = datetime.date(2015, 1, 1)

# while date < datetime.date(2015, 1, 15): # 테스트용
while date < datetime.date(2019, 11, 1):
    start_date = date.isoformat()

    seat = pd.read_html(f'일별상영점유율-{start_date}.html', encoding='utf-8')

    for i in range(1,8)[::-1]:
         df2 = seat[i][:-1]
         df = pd.concat([df, df2])
        
    date += datetime.timedelta(days=7)

# %%
connection = sqlite3.connect('show.db')
df.to_sql('show_daily_propotion', connection, index=False
#           , if_exists='replace' # 같은 db 에 덮어쓰는 코드
         )
pd.read_sql('select * from show_daily_propotion', connection)
# Out:
#        순위              영화명         개봉일  상영횟수    상영점유율         매출액  \
# 0       1             국제시장  2014-12-17  4650  45.651%  6129982500
# 1       2  님아, 그 강을 건너지 마오  2014-11-27  1979  19.429%  1479015600
# 2       3             기술자들  2014-12-24  1886  18.516%  1299883700
# 3       4    개를 훔치는 완벽한 방법  2014-12-31   650   6.381%   299346400
# 4       5              상의원  2014-12-24   491    4.82%   230484800
# ...    ..              ...         ...   ...      ...         ...
# 58809  28     나쁜 녀석들: 더 무비  2019-09-11     1   0.015%        6000
# 58810  28   1919유관순-그녀들의조국        None     1   0.015%        2000
# 58811  28              이어도        None     1   0.015%           0
# 58812  28  뽀로로 극장판 보물섬 대모험  2019-04-25     1   0.015%       79000
# 58813  28               로망  2019-04-03     1   0.015%      750000
#
#              누적매출액     관객수    누적관객수
# 0      47219550096  751754  6097431
# 1      31324845079  178941  4025319
# 2      14952363848  160371  1938454
# 3        608002300   37741    80633
# 4       5524209364   28439   705071
# ...            ...     ...      ...
# 58809  39552792124       1  4573112
# 58810        52000       1       26
# 58811      3763500       0      799
# 58812   5886383900      79   766843
# 58813    591424900     150    80079
#
# [58814 rows x 9 columns]

# %% [markdown]
# # 일별 스크린점유율(Frank)

# %%
# 일별 스크린점유율 http://www.kobis.or.kr/kobis/business/stat/boxs/findDailyScreenTicketList.do
NAME = 'findDailyScreenTicketList'
URL = f'http://www.kobis.or.kr/kobis/business/stat/boxs/{NAME}.do'

date = datetime.date(2015, 1, 1)

while date < datetime.date(2015, 1, 15): # 테스트용
# while date < datetime.date(2019, 11, 1):
    start_date = date.isoformat()
    end_date = (date + datetime.timedelta(days=6)).isoformat()
    print(start_date, '~', end_date)
    os.system(f'curl "{URL}?loadEnd=0&dmlMode=excel&' \
              f'startDate={start_date}&endDate={end_date}&repNationCd=1"' \
              f' > 일별스크린점유율-{start_date}.html')
    date += datetime.timedelta(days=7)
# Out:
# 2015-01-01 ~ 2015-01-07
# 2015-01-08 ~ 2015-01-14

# %%
df = pd.DataFrame()

date = datetime.date(2015, 1, 1)

while date < datetime.date(2015, 1, 15): # 테스트용
# while date < datetime.date(2019, 11, 1):
    start_date = date.isoformat()

    seat = pd.read_html(f'일별스크린점유율-{start_date}.html', encoding='utf-8')

    for i in range(1,8)[::-1]:
         df2 = seat[i][:-1]
         df = pd.concat([df, df2])
        
    date += datetime.timedelta(days=7)

# %%
connection = sqlite3.connect('screen.db')
df.to_sql('show_daily_propotion', connection, index=False
#           , if_exists='replace' # 같은 db 에 덮어쓰는 코드
         )
pd.read_sql('select * from show_daily_propotion', connection)
# Out:
#      순위                            영화명         개봉일  스크린수 스크린점유율         매출액  \
# 0     1                           국제시장  2014-12-17   941  35.8%  6129982500
# 1     2                님아, 그 강을 건너지 마오  2014-11-27   473  18.0%  1479015600
# 2     3                           기술자들  2014-12-24   464  17.7%  1299883700
# 3     4                            상의원  2014-12-24   258   9.8%   230484800
# 4     5                  개를 훔치는 완벽한 방법  2014-12-31   196   7.5%   299346400
# 5     6                   더 테너 리리코 스핀토  2014-12-31   169   6.4%    69620500
# 6     7             뽀로로 극장판 눈요정 마을 대모험        None    66   2.5%    27846600
# 7     8                           쿼바디스  2014-12-10    12   0.5%     4046900
# 8     9                             목숨  2014-12-04    10   0.4%     1399500
# 9    10                 그 사람 그 사랑 그 세상  2014-11-20     7   0.3%     9467000
# 10   11                           파티51  2014-12-11     4   0.2%      225000
# 11   11                           다이빙벨  2014-10-23     4   0.2%      627000
# 12   13                             카트  2014-11-13     3   0.1%     1720800
# 13   13                       민우씨 오는 날        None     3   0.1%       87000
# 14   13                        제자, 옥한흠  2014-10-30     3   0.1%      687000
# 15   16                            빅매치  2014-11-27     2   0.1%           0
# 16   16                             거인  2014-11-13     2   0.1%      156000
# 17   16                        두 번째 엄마  2014-12-31     2   0.1%       32000
# 18   19                             명기  2014-12-30     1   0.0%        9000
# 19   19          GROW: 인피니트의 리얼 청춘 라이프  2014-12-04     1   0.0%       54000
# 20   19                         장군의 아들  1990-06-09     1   0.0%      416000
# 21   19                            앙상블  2014-12-18     1   0.0%      140000
# 22   19                            숫호구  2014-08-07     1   0.0%       14000
# 23   19                        카토 프로젝트  2014-04-17     1   0.0%        2000
# 24   19                         자유의 언덕  2014-09-04     1   0.0%      207000
# 25   19                      한여름의 판타지아  2015-06-11     1   0.0%      374600
# 26    1                           국제시장  2014-12-17   930  35.5%  3782877729
# 27    2                           기술자들  2014-12-24   481  18.4%   758620771
# 28    3                님아, 그 강을 건너지 마오  2014-11-27   471  18.0%   809774300
# 29    4                            상의원  2014-12-24   264  10.1%   149272900
# ..   ..                            ...         ...   ...    ...         ...
# 362   2                            허삼관  2015-01-14   584  24.9%   551479100
# 363   3                         오늘의 연애  2015-01-14   577  24.6%  1032903000
# 364   4                님아, 그 강을 건너지 마오  2014-11-27   264  11.3%    64991300
# 365   5                           기술자들  2014-12-24   146   6.2%    28781000
# 366   6                            워킹걸  2015-01-07    56   2.4%     9121500
# 367   7                  개를 훔치는 완벽한 방법  2014-12-31    23   1.0%     9173700
# 368   8                           쿼바디스  2014-12-10    12   0.5%     1364400
# 369   9                             목숨  2014-12-04     8   0.3%      466000
# 370   9                             설해  2015-01-08     8   0.3%      183000
# 371  11                            상의원  2014-12-24     5   0.2%      504000
# 372  11                   더 테너 리리코 스핀토  2014-12-31     5   0.2%     2859000
# 373  11             뽀로로 극장판 눈요정 마을 대모험        None     5   0.2%      721000
# 374  14                           파티51  2014-12-11     4   0.2%      210000
# 375  15                 그 사람 그 사랑 그 세상  2014-11-20     3   0.1%      176000
# 376  16                        고양이 장례식  2015-01-15     2   0.1%     1533000
# 377  17                       춘하추동 로맨스  2014-12-04     1   0.0%       21000
# 378  17                            숫호구  2014-08-07     1   0.0%       22000
# 379  17                            악사들  2014-12-04     1   0.0%       12000
# 380  17                        카토 프로젝트  2014-04-17     1   0.0%        4000
# 381  17                        두 번째 엄마  2014-12-31     1   0.0%       14000
# 382  17                        제자, 옥한흠  2014-10-30     1   0.0%       40000
# 383  17                           다이빙벨  2014-10-23     1   0.0%       96000
# 384  17                             카트  2014-11-13     1   0.0%      236000
# 385  17                           레드 툼  2015-07-09     1   0.0%       35000
# 386  17                             순천  2014-09-04     1   0.0%       10000
# 387  17                            족구왕  2014-08-21     1   0.0%       40000
# 388  17                              못  2014-11-20     1   0.0%       10000
# 389  17                            앙상블  2014-12-18     1   0.0%       34000
# 390  17  독립영화발표회(251회) - 박영석 프로그래머 추천전        None     1   0.0%           0
# 391  17                         자유의 언덕  2014-09-04     1   0.0%       48000
#
#            누적매출액     관객수    누적관객수
# 0    47219550096  751754  6097431
# 1    31324845079  178941  4025319
# 2    14952363848  160371  1938454
# 3     5524209364   28439   705071
# 4      608002300   37741    80633
# 5      200984700    8446    26316
# 6     1188395900    5561   237436
# 7      117029800     509    15399
# 8      275635600     179    35844
# 9      162552500    1202    22070
# 10      13434800      34     1804
# 11     336231500      79    48571
# 12    5914397433     198   812688
# 13       3415500      17      695
# 14     356418200      87    48547
# 15    8952096578       0  1177438
# 16     175489400      23    23176
# 17        552000       4      153
# 18        647000       1      242
# 19     189463200       9    23874
# 20       1446000     208      723
# 21       6045500      16      778
# 22      16270000       2     2105
# 23       1886000       1      619
# 24     309165827      23    38101
# 25        996100      48      148
# 26   51002427825  470690  6568121
# 27   15710984619   95119  2033573
# 28   32134619379  100585  4125904
# 29    5673482264   18455   723526
# ..           ...     ...      ...
# 362    615567100   73635    81503
# 363   1099473000  133838   141522
# 364  36580783379    9090  4696415
# 365  19736744683    3760  2544717
# 366   1085098979    1186   134144
# 367   1684918765    1337   221805
# 368    141777300     219    18836
# 369    283397600      64    36867
# 370     27419500      23     3653
# 371   6198263964      72   789628
# 372    375039941     387    48526
# 373   1269500700     167   254045
# 374     15143800      29     2037
# 375    186986500      27    25215
# 376     11512600     175     1420
# 377      8119800       3     1200
# 378     16348000       4     2117
# 379      7733200       2     1372
# 380      1918000       2      635
# 381      1010000       2      239
# 382    359310200       5    48904
# 383    341616500      12    49300
# 384   5924979433      30   813982
# 385      1257000       7      230
# 386     22832200       5     3610
# 387    359459000       5    45666
# 388     16941600       2     2368
# 389      6939500       6      900
# 390            0       0        0
# 391    310619827       6    38286
#
# [392 rows x 9 columns]

# %% [markdown]
# # 상영내역(Andy)

# %%
# 상영내역 http://www.kobis.or.kr/kobis/business/mast/thea/findShowHistorySc.do

#http://www.kobis.or.kr/kobis/business/mast/thea/findShowHistoryScXls.do
#?theaCd=001123&theaArea=Y&
#showStartDt=2019-11-19&showEndDt=2019-11-26"

http://www.kobis.or.kr/kobis/business/mast/thea/findShowHistoryScXls.do?theaCd=001123&theaArea=Y&showStartDt=2018-01-01&showEndDt=2018-12-31&choice=2&sTheaNm=CGV%20강남"

URL = f'http://www.kobis.or.kr/kobis/business/mast/thea/findShowHistoryScXls.do'

showStartDt = 2015-01-01
showEndDt = 2019-10-31
sTheaNm = CGV%20강남
    
os.system(f'curl "{URL}?showStartDt={showStartDt}&endDate={showEndDt}&sTheaNm={sTheaNm}"' \
          f' > 일별상영점유율-{start_date}.html')

date = datetime.date(2015, 1, 1)

while date < datetime.date(2019, 11, 1):
    start_date = date.isoformat()
    end_date = (date + datetime.timedelta(days=6)).isoformat()
    print(start_date, '~', end_date)
    os.system(f'curl "{URL}?loadEnd=0&dmlMode=excel&' \
              f'startDate={start_date}&endDate={end_date}&repNationCd=1"' \
              f' > 일별상영점유율-{start_date}.html')
    date += datetime.timedelta(days=7)
    
    heaCd: 002041
theaArea: Y
showStartDt: 2019-11-20
showEndDt: 2019-11-27
sWideareaCd: 
sBasareaCd: 
sTheaCd: 
choice: 2
sTheaNm: CGV  김포한강
